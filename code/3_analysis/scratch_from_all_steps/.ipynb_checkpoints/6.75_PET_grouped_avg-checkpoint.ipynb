# %%
# average the output of 6.5_PET_yeargrouped.py across years such that you end up with a stack of only 6 images
# Anna Boser Jan 5, 2022

# %%
from pyprojroot import here
import rasterio
import datetime
import numpy as np
import pandas as pd
import pickle
from osgeo import gdal, gdalconst
import matplotlib.pyplot as plt

# %%
img = rasterio.open(here("./data/intermediate/PET/PET_yeargrouped_avg.tif")) # NA values are -3.4e+38
array = np.array(img.read())

# %%
plt.figure()
plt.imshow(array[0,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[1,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[2,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[3,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[4,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[5,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[6,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[7,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[8,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[9,:,:])
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(array[10,:,:])
plt.colorbar()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1dc9e58e3aa1> in <module>
#       1 plt.figure()
# ----> 2 plt.imshow(array[11,:,:])
#       3 plt.colorbar()
#       4 plt.show()
#
# IndexError: index 11 is out of bounds for axis 0 with size 11
