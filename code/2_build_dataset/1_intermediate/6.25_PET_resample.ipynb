# %%
from osgeo import gdal
import numpy as np
import matplotlib.pyplot as plt
from pyprojroot import here

# %%
from osgeo.gdal_array import *

# %%
PET = gdal.Open(str(here("./data/intermediate/PET/PETbrick_OGres.tif")))

# %%
band = PET.GetRasterBand(1)
array = band.ReadAsArray()

# %%
plt.figure()
plt.imshow(array)
plt.colorbar()
plt.show()

# %%
maskneg = np.where((array < 0), 0, array)
plt.figure()
plt.imshow(maskneg)
plt.show()

# %%
CA_grid = gdal.Open(str(here("data/intermediate/CA_grid.tif")))

# %%
CA_grid_band = ds.GetRasterBand(1)
CA_grid_array = band.ReadAsArray()
plt.figure()
plt.imshow(CA_grid_array)
plt.colorbar()
plt.show()

# %%
CA_grid.GetProjection()
# Out:
# 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'

# %%
CA_grid.GetGeoTransform()
# Out:
# (-124.409740821737,
#  0.0006309954707866042,
#  0.0,
#  42.0097687956553,
#  0.0,
#  -0.0006309954708085768)

# %%
PET.GetProjection()
# Out:
# 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'

# %%
PET.GetGeoTransform()
# Out:
# (-124.5,
#  0.10097088860076608,
#  0.0,
#  42.099998474121094,
#  0.0,
#  -0.10105261551706414)

# %%
PET_resampled = gdal.Warp(str(here("data/intermediate/PET/PETbrick.tif")), xRes =
